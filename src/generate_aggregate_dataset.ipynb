# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
GENRES = ["classical", "country", "edm", "hip-hop", "jazz", "pop", "rap", "rnb", "rock"]

# %%
all_tracks = pd.DataFrame()

for genre in GENRES:
    genre = pd.read_pickle(f"../data/spotify_dataset_{genre}.pkl")
    all_tracks = pd.concat([all_tracks, genre])

# Finding all duplicates
all_dupes = all_tracks[all_tracks.index.duplicated()]
all_dupes.shape
# Out:
# (833, 16)

# %%
# Creating multilabels
df = all_tracks
df[[GENRES]] = 0
df.sample(n=1)
# Out:
#                                 artists          name    genre  danceability  \
# 52gqeRlrBE7hqMlRxEsi6y  [Ja Rule, Case]  Livin' It Up  hip-hop         0.874
#
#                         energy  key  loudness  mode  speechiness  \
# 52gqeRlrBE7hqMlRxEsi6y   0.768    6    -4.086     1        0.311
#
#                         acousticness  ...  time_signature  classical  country  \
# 52gqeRlrBE7hqMlRxEsi6y        0.0554  ...               4          0        0
#
#                         edm  hip-hop  jazz  pop  rap  rnb  rock
# 52gqeRlrBE7hqMlRxEsi6y    0        0     0    0    0    0     0
#
# [1 rows x 25 columns]

# %%
# Update genre to 1 for each song's genre
for genre in GENRES:
    df.loc[df['genre'] == genre, genre] = 1
df.sample(n=3)
# Out:
#                                      artists   name genre  danceability  \
# 6uugzqDWMG8qVl0h6DdYVs  [Miles Davis Sextet]  Donna  jazz         0.584
# 4ReyTz0y3TGkX48wO3Llot       [Faith No More]   Epic  rock         0.358
# 4pYetgD3nCixJrXCjywu78         [Genix, LYCA]   Numb   edm         0.582
#
#                         energy  key  loudness  mode  speechiness  \
# 6uugzqDWMG8qVl0h6DdYVs   0.440    5    -9.696     0       0.0329
# 4ReyTz0y3TGkX48wO3Llot   0.893    4    -7.486     0       0.1200
# 4pYetgD3nCixJrXCjywu78   0.878    2    -8.841     0       0.0448
#
#                         acousticness  ...  time_signature  classical  country  \
# 6uugzqDWMG8qVl0h6DdYVs       0.71300  ...               4          0        0
# 4ReyTz0y3TGkX48wO3Llot       0.02220  ...               4          0        0
# 4pYetgD3nCixJrXCjywu78       0.00124  ...               4          0        0
#
#                         edm  hip-hop  jazz  pop  rap  rnb  rock
# 6uugzqDWMG8qVl0h6DdYVs    0        0     1    0    0    0     0
# 4ReyTz0y3TGkX48wO3Llot    0        0     0    0    0    0     1
# 4pYetgD3nCixJrXCjywu78    1        0     0    0    0    0     0
#
# [3 rows x 25 columns]

# %%
# Now that every song has a genre attached in the multilabels, drop the genre column
df.drop('genre', axis=1, inplace=True)
df
# Out:
#                                                                   artists  \
# 5bu9A6uphPWg39RC3ZKeku               [Johann Sebastian Bach, Glenn Gould]
# 1Oo7XEqkrwifJn17aA0ocF                  [Johannes Brahms, Arcadi Volodos]
# 1upQiytDIEZfl9ItruoXuC  [George Frideric Handel, Alexander Briger, Aca...
# 47DAIw0cnLLHEXcuUHHC6a          [Franz Joseph Haydn, Alban Berg Quartett]
# 3DNRdudZ2SstnDCVKFdXxG                 [Ludwig van Beethoven, Paul Lewis]
# ...                                                                   ...
# 6vUssnJuFxgw1EFG717Kd5                                      [The Zombies]
# 1p50Ir1Hm6Sa1urjaLGi7L                            [Anthrax, Public Enemy]
# 7LbfuQVct78YoghmoPtsQ8                                    [Grateful Dead]
# 3T76zPJz3tWL27FrjJe2ot                                       [Jack White]
# 2VnkxWob7ooT5NrN9WtctI                                   [Band Of Skulls]
#
#                                                                      name  \
# 5bu9A6uphPWg39RC3ZKeku                 Goldberg Variations, BWV 988: Aria
# 1Oo7XEqkrwifJn17aA0ocF  Sechs Klavierstücke, Op. 118: II. Intermezzo i...
# 1upQiytDIEZfl9ItruoXuC  Handel / Orch. Hale: Keyboard Suite No. 4 in D...
# 47DAIw0cnLLHEXcuUHHC6a  Haydn: String Quartet in C Major, Op. 76 No. 3...
# 3DNRdudZ2SstnDCVKFdXxG  Sonata No. 14 "Moonlight" in C-Sharp Minor", O...
# ...                                                                   ...
# 6vUssnJuFxgw1EFG717Kd5                       This Will Be Our Year [Mono]
# 1p50Ir1Hm6Sa1urjaLGi7L                                    Bring The Noise
# 7LbfuQVct78YoghmoPtsQ8                        Casey Jones - 2013 Remaster
# 3T76zPJz3tWL27FrjJe2ot                                          Lazaretto
# 2VnkxWob7ooT5NrN9WtctI                                Asleep at the Wheel
#
#                         danceability   energy  key  loudness  mode  \
# 5bu9A6uphPWg39RC3ZKeku        0.4540  0.01390    4   -29.966     0
# 1Oo7XEqkrwifJn17aA0ocF        0.2990  0.00626    9   -30.923     1
# 1upQiytDIEZfl9ItruoXuC        0.0939  0.03360    2   -24.041     0
# 47DAIw0cnLLHEXcuUHHC6a        0.5000  0.12800    7   -18.042     1
# 3DNRdudZ2SstnDCVKFdXxG        0.1840  0.00527    1   -37.264     0
# ...                              ...      ...  ...       ...   ...
# 6vUssnJuFxgw1EFG717Kd5        0.4000  0.51600    9    -9.317     1
# 1p50Ir1Hm6Sa1urjaLGi7L        0.6010  0.83100    2    -8.582     1
# 7LbfuQVct78YoghmoPtsQ8        0.6710  0.40500    0   -10.052     1
# 3T76zPJz3tWL27FrjJe2ot        0.3810  0.83800    6    -6.562     0
# 2VnkxWob7ooT5NrN9WtctI        0.3480  0.63300    2    -7.025     1
#
#                         speechiness  acousticness  instrumentalness  ...  \
# 5bu9A6uphPWg39RC3ZKeku       0.0514      0.995000          0.943000  ...
# 1Oo7XEqkrwifJn17aA0ocF       0.0478      0.994000          0.901000  ...
# 1upQiytDIEZfl9ItruoXuC       0.0606      0.927000          0.830000  ...
# 47DAIw0cnLLHEXcuUHHC6a       0.0489      0.953000          0.618000  ...
# 3DNRdudZ2SstnDCVKFdXxG       0.0432      0.995000          0.887000  ...
# ...                             ...           ...               ...  ...
# 6vUssnJuFxgw1EFG717Kd5       0.0316      0.779000          0.000024  ...
# 1p50Ir1Hm6Sa1urjaLGi7L       0.1700      0.000860          0.000000  ...
# 7LbfuQVct78YoghmoPtsQ8       0.0392      0.385000          0.000000  ...
# 3T76zPJz3tWL27FrjJe2ot       0.0709      0.004600          0.000038  ...
# 2VnkxWob7ooT5NrN9WtctI       0.0317      0.000285          0.011500  ...
#
#                         time_signature  classical  country  edm  hip-hop  \
# 5bu9A6uphPWg39RC3ZKeku               4          1        0    0        0
# 1Oo7XEqkrwifJn17aA0ocF               4          1        0    0        0
# 1upQiytDIEZfl9ItruoXuC               3          1        0    0        0
# 47DAIw0cnLLHEXcuUHHC6a               4          1        0    0        0
# 3DNRdudZ2SstnDCVKFdXxG               3          1        0    0        0
# ...                                ...        ...      ...  ...      ...
# 6vUssnJuFxgw1EFG717Kd5               3          0        0    0        0
# 1p50Ir1Hm6Sa1urjaLGi7L               4          0        0    0        0
# 7LbfuQVct78YoghmoPtsQ8               4          0        0    0        0
# 3T76zPJz3tWL27FrjJe2ot               4          0        0    0        0
# 2VnkxWob7ooT5NrN9WtctI               4          0        0    0        0
#
#                         jazz  pop  rap  rnb  rock
# 5bu9A6uphPWg39RC3ZKeku     0    0    0    0     0
# 1Oo7XEqkrwifJn17aA0ocF     0    0    0    0     0
# 1upQiytDIEZfl9ItruoXuC     0    0    0    0     0
# 47DAIw0cnLLHEXcuUHHC6a     0    0    0    0     0
# 3DNRdudZ2SstnDCVKFdXxG     0    0    0    0     0
# ...                      ...  ...  ...  ...   ...
# 6vUssnJuFxgw1EFG717Kd5     0    0    0    0     1
# 1p50Ir1Hm6Sa1urjaLGi7L     0    0    0    0     1
# 7LbfuQVct78YoghmoPtsQ8     0    0    0    0     1
# 3T76zPJz3tWL27FrjJe2ot     0    0    0    0     1
# 2VnkxWob7ooT5NrN9WtctI     0    0    0    0     1
#
# [7464 rows x 24 columns]

# %%
# Merge duplicates together
tracks_and_genres = df.groupby(df.index).agg({genre: 'sum' for genre in GENRES})
tracks_and_genres
# Out:
#                         classical  country  edm  hip-hop  jazz  pop  rap  rnb  \
# 003vvx7Niy0yvhvHt4a68B          0        0    0        0     0    0    0    0
# 00762tXbSj2w2bQMVydJZn          0        0    0        1     0    0    0    0
# 00CXUMREit80f2McJsjcIz          1        0    0        0     0    0    0    0
# 00KyYtT6NaXwbPecina5Pj          0        1    0        0     0    0    0    0
# 00Mb3DuaIH1kjrwOku9CGU          0        0    0        0     0    1    0    0
# ...                           ...      ...  ...      ...   ...  ...  ...  ...
# 7zSEUE2ebqU2zS3ibaNw8r          0        0    1        0     0    0    0    0
# 7zVZF0OgDJkFJohnlKwEpa          0        1    0        0     0    0    0    0
# 7zjEyeBsaw9gV0jofJLfOM          0        0    0        0     0    0    1    0
# 7zmleW3XZx0uUsL2CkFuDe          0        0    0        0     0    0    0    1
# 7zxRMhXxJMQCeDDg0rKAVo          0        0    0        1     0    0    1    0
#
#                         rock
# 003vvx7Niy0yvhvHt4a68B     1
# 00762tXbSj2w2bQMVydJZn     0
# 00CXUMREit80f2McJsjcIz     0
# 00KyYtT6NaXwbPecina5Pj     0
# 00Mb3DuaIH1kjrwOku9CGU     0
# ...                      ...
# 7zSEUE2ebqU2zS3ibaNw8r     0
# 7zVZF0OgDJkFJohnlKwEpa     0
# 7zjEyeBsaw9gV0jofJLfOM     0
# 7zmleW3XZx0uUsL2CkFuDe     0
# 7zxRMhXxJMQCeDDg0rKAVo     0
#
# [6631 rows x 9 columns]

# %%
# Get unique tracks with audio features only
tracks_without_dupes = df[~df.index.duplicated(keep='first')]
tracks_without_dupes = tracks_without_dupes.drop(GENRES, axis=1)
tracks_without_dupes.sample(n=3)
# Out:
#                                  artists        name  danceability  energy  \
# 2u34ZVPVlr7hfN7vDr1512  [Ruben Studdard]  Sorry 2004         0.721   0.472
# 7IzN1BfaQ8fmTHYPRPhNws   [Azealia Banks]      Luxury         0.689   0.910
# 2grSOc6HNTXQQXNoRKt9UM      [Charli XCX]   Good Ones         0.764   0.672
#
#                         key  loudness  mode  speechiness  acousticness  \
# 2u34ZVPVlr7hfN7vDr1512    9    -7.574     1       0.0619        0.0760
# 7IzN1BfaQ8fmTHYPRPhNws    8    -6.808     1       0.1840        0.0196
# 2grSOc6HNTXQQXNoRKt9UM    7    -5.947     0       0.0293        0.0720
#
#                         instrumentalness  liveness  valence    tempo  \
# 2u34ZVPVlr7hfN7vDr1512          0.000000    0.3320    0.462  129.964
# 7IzN1BfaQ8fmTHYPRPhNws          0.000018    0.2720    0.569  121.988
# 2grSOc6HNTXQQXNoRKt9UM          0.000003    0.0806    0.789  129.049
#
#                         duration_ms  time_signature
# 2u34ZVPVlr7hfN7vDr1512       261867               4
# 7IzN1BfaQ8fmTHYPRPhNws       168097               4
# 2grSOc6HNTXQQXNoRKt9UM       136614               4

# %%
# Merge unique tracks with multilabels
all_tracks_cleaned = pd.merge(tracks_without_dupes, tracks_and_genres, left_index=True, right_index=True)
all_tracks_cleaned.sample(n=3)
# Out:
#                                 artists             name  danceability  \
# 6EFeY62awexVgzxgSnZng2     [De La Soul]  Me Myself And I         0.898
# 7m88zZK8l7ydUJDjaL3h09  [Julie Roberts]    Wake Up Older         0.662
# 2ER50sjIrGpBHj4TsZC5vu  [Amel Larrieux]           Get Up         0.628
#
#                         energy  key  loudness  mode  speechiness  \
# 6EFeY62awexVgzxgSnZng2   0.920    5    -7.859     1       0.0638
# 7m88zZK8l7ydUJDjaL3h09   0.238   10    -9.682     1       0.0344
# 2ER50sjIrGpBHj4TsZC5vu   0.495    7    -8.601     1       0.1300
#
#                         acousticness  instrumentalness  ...  time_signature  \
# 6EFeY62awexVgzxgSnZng2        0.0713          0.000056  ...               4
# 7m88zZK8l7ydUJDjaL3h09        0.5170          0.000000  ...               4
# 2ER50sjIrGpBHj4TsZC5vu        0.3680          0.000004  ...               4
#
#                         classical  country  edm  hip-hop  jazz  pop  rap  rnb  \
# 6EFeY62awexVgzxgSnZng2          0        0    0        1     0    0    0    0
# 7m88zZK8l7ydUJDjaL3h09          0        1    0        0     0    0    0    0
# 2ER50sjIrGpBHj4TsZC5vu          0        0    0        0     0    0    0    1
#
#                         rock
# 6EFeY62awexVgzxgSnZng2     0
# 7m88zZK8l7ydUJDjaL3h09     0
# 2ER50sjIrGpBHj4TsZC5vu     0
#
# [3 rows x 24 columns]

# %%
# Inspect two previously duplicated tracks and check if more than one genre is listed
all_tracks_cleaned.loc[['1rIKgCH4H52lrvDcz50hS8', '2wxO3ZydJTZRi4Bbc02q7i']]
# Out:
#                                            artists       name  danceability  \
# 1rIKgCH4H52lrvDcz50hS8              [Zara Larsson]  Lush Life         0.694
# 2wxO3ZydJTZRi4Bbc02q7i  [Scarface, Johnny P, 2Pac]      Smile         0.700
#
#                         energy  key  loudness  mode  speechiness  \
# 1rIKgCH4H52lrvDcz50hS8   0.712    7    -3.923     0        0.046
# 2wxO3ZydJTZRi4Bbc02q7i   0.402    5    -9.930     0        0.278
#
#                         acousticness  instrumentalness  ...  time_signature  \
# 1rIKgCH4H52lrvDcz50hS8        0.1320          0.000000  ...               4
# 2wxO3ZydJTZRi4Bbc02q7i        0.0498          0.000001  ...               4
#
#                         classical  country  edm  hip-hop  jazz  pop  rap  rnb  \
# 1rIKgCH4H52lrvDcz50hS8          0        0    1        0     0    1    0    0
# 2wxO3ZydJTZRi4Bbc02q7i          0        0    0        1     0    0    1    0
#
#                         rock
# 1rIKgCH4H52lrvDcz50hS8     0
# 2wxO3ZydJTZRi4Bbc02q7i     0
#
# [2 rows x 24 columns]

# %%
all_tracks_cleaned.to_pickle("../data/spotify_dataset_all.pkl")
