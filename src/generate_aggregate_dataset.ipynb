# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
GENRES = ["classical", "country", "edm", "hip-hop", "jazz", "pop", "rap", "rnb", "rock"]

# %%
all_tracks = pd.DataFrame()

for genre in GENRES:
    genre = pd.read_pickle(f"../data/spotify_dataset_{genre}.pkl")
    all_tracks = pd.concat([all_tracks, genre])

# Finding all duplicates
all_dupes = all_tracks[all_tracks.index.duplicated()]
all_dupes.shape
# Out:
# (835, 16)

# %%
# Creating multilabels
df = all_tracks
df[[GENRES]] = 0
df.sample(n=1)
# Out:
#                                             artists  \
# 3QFInJAm9eyaho5vBzxInN  [Baby Keem, Kendrick Lamar]
#
#                                                      name genre  danceability  \
# 3QFInJAm9eyaho5vBzxInN  family ties (with Kendrick Lamar)   rap         0.711
#
#                         energy  key  loudness  mode  speechiness  \
# 3QFInJAm9eyaho5vBzxInN   0.611    1    -5.453     1         0.33
#
#                         acousticness  ...  time_signature  classical  country  \
# 3QFInJAm9eyaho5vBzxInN       0.00588  ...               4          0        0
#
#                         edm  hip-hop  jazz  pop  rap  rnb  rock
# 3QFInJAm9eyaho5vBzxInN    0        0     0    0    0    0     0
#
# [1 rows x 25 columns]

# %%
# Update genre to 1 for each song's genre
for genre in GENRES:
    df.loc[df['genre'] == genre, genre] = 1
df.sample(n=3)
# Out:
#                                                      artists  \
# 6EafRI0UtUidrZbbKpFRYq  [Aluna, Diplo, Durante, AlunaGeorge]
# 2MJz8BxxMsERULatmBikDH                         [Pink Sweat$]
# 4I3573QbRpER4HPzyFSFJa                      [The Raconteurs]
#
#                                         name genre  danceability  energy  key  \
# 6EafRI0UtUidrZbbKpFRYq       Forget About Me   edm         0.721   0.894    3
# 2MJz8BxxMsERULatmBikDH           At My Worst   pop         0.813   0.415    0
# 4I3573QbRpER4HPzyFSFJa  Salute Your Solution  rock         0.266   0.946    9
#
#                         loudness  mode  speechiness  acousticness  ...  \
# 6EafRI0UtUidrZbbKpFRYq    -7.590     0       0.0488       0.04280  ...
# 2MJz8BxxMsERULatmBikDH    -5.926     1       0.0349       0.77700  ...
# 4I3573QbRpER4HPzyFSFJa    -2.855     1       0.1710       0.00781  ...
#
#                         time_signature  classical  country  edm  hip-hop  \
# 6EafRI0UtUidrZbbKpFRYq               4          0        0    1        0
# 2MJz8BxxMsERULatmBikDH               4          0        0    0        0
# 4I3573QbRpER4HPzyFSFJa               4          0        0    0        0
#
#                         jazz  pop  rap  rnb  rock
# 6EafRI0UtUidrZbbKpFRYq     0    0    0    0     0
# 2MJz8BxxMsERULatmBikDH     0    1    0    0     0
# 4I3573QbRpER4HPzyFSFJa     0    0    0    0     1
#
# [3 rows x 25 columns]

# %%
# Now that every song has a genre attached in the multilabels, drop the genre column
df.drop('genre', axis=1, inplace=True)
df.sample(n=1)
# Out:
#                                                    artists  \
# 3oyc1mIdCBGaU55wX7otqM  [Elvis Costello & The Attractions]
#
#                                               name  danceability  energy  key  \
# 3oyc1mIdCBGaU55wX7otqM  Pump It Up - 2021 Remaster         0.645   0.809   11
#
#                         loudness  mode  speechiness  acousticness  \
# 3oyc1mIdCBGaU55wX7otqM     -6.12     1       0.0385       0.00921
#
#                         instrumentalness  ...  time_signature  classical  \
# 3oyc1mIdCBGaU55wX7otqM           0.00108  ...               4          0
#
#                         country  edm  hip-hop  jazz  pop  rap  rnb  rock
# 3oyc1mIdCBGaU55wX7otqM        0    0        0     0    0    0    0     1
#
# [1 rows x 24 columns]

# %%
# Merge duplicates together
tracks_and_genres = df.groupby(df.index).agg({genre: 'sum' for genre in GENRES})
tracks_and_genres
# Out:
#                         classical  country  edm  hip-hop  jazz  pop  rap  rnb  \
# 003vvx7Niy0yvhvHt4a68B          0        0    0        0     0    0    0    0
# 00762tXbSj2w2bQMVydJZn          0        0    0        1     0    0    0    0
# 00CXUMREit80f2McJsjcIz          1        0    0        0     0    0    0    0
# 00KyYtT6NaXwbPecina5Pj          0        1    0        0     0    0    0    0
# 00Mb3DuaIH1kjrwOku9CGU          0        0    0        0     0    1    0    0
# ...                           ...      ...  ...      ...   ...  ...  ...  ...
# 7zI3nF4mahUbVKjxRjhmEt          0        0    0        0     1    0    0    0
# 7zSEUE2ebqU2zS3ibaNw8r          0        0    1        0     0    0    0    0
# 7zjEyeBsaw9gV0jofJLfOM          0        0    0        1     0    0    1    0
# 7zmleW3XZx0uUsL2CkFuDe          0        0    0        0     0    1    0    1
# 7zxRMhXxJMQCeDDg0rKAVo          0        0    0        1     0    0    1    0
#
#                         rock
# 003vvx7Niy0yvhvHt4a68B     1
# 00762tXbSj2w2bQMVydJZn     0
# 00CXUMREit80f2McJsjcIz     0
# 00KyYtT6NaXwbPecina5Pj     0
# 00Mb3DuaIH1kjrwOku9CGU     0
# ...                      ...
# 7zI3nF4mahUbVKjxRjhmEt     0
# 7zSEUE2ebqU2zS3ibaNw8r     0
# 7zjEyeBsaw9gV0jofJLfOM     0
# 7zmleW3XZx0uUsL2CkFuDe     0
# 7zxRMhXxJMQCeDDg0rKAVo     0
#
# [6616 rows x 9 columns]

# %%
# Get unique tracks with audio features only
tracks_without_dupes = df[~df.index.duplicated(keep='first')]
tracks_without_dupes = tracks_without_dupes.drop(GENRES, axis=1)
tracks_without_dupes.sample(n=3)
# Out:
#                                         artists                name  \
# 0vQdNTM18KusMJJrXWXDAy  [Quintino, Thomas Gold]             Quechua
# 4djIFfof5TpbSGRZUpsTXq                   [COIN]       Talk Too Much
# 3Up1MsHqcxUVgB2iuqFRq2   [Kasbo, Frida Sundemo]  Shut The World Out
#
#                         danceability  energy  key  loudness  mode  \
# 0vQdNTM18KusMJJrXWXDAy         0.592   0.983    5    -3.429     0
# 4djIFfof5TpbSGRZUpsTXq         0.598   0.888    4    -5.119     1
# 3Up1MsHqcxUVgB2iuqFRq2         0.496   0.679    8    -6.893     1
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# 0vQdNTM18KusMJJrXWXDAy       0.0840      0.000611           0.00764     0.175
# 4djIFfof5TpbSGRZUpsTXq       0.0807      0.009470           0.00000     0.347
# 3Up1MsHqcxUVgB2iuqFRq2       0.0345      0.030800           0.00327     0.316
#
#                         valence    tempo  duration_ms  time_signature
# 0vQdNTM18KusMJJrXWXDAy    0.375  131.967       179091               4
# 4djIFfof5TpbSGRZUpsTXq    0.482  103.966       187133               4
# 3Up1MsHqcxUVgB2iuqFRq2    0.224  105.059       268966               4

# %%
# Merge unique tracks with multilabels
all_tracks_cleaned = pd.merge(tracks_without_dupes, tracks_and_genres, left_index=True, right_index=True)
all_tracks_cleaned.sample(n=3)
# Out:
#                                                 artists  \
# 6rdmyLJtIibFRaCU7XRg3x                    [Josh Gracin]
# 2WN7xpcY4zmcqF57HFEGZY  [Belly, The Weeknd, Young Thug]
# 0jTTjg6q4jsd2RhuHwTvLj                 [Ashley Tisdale]
#
#                                                   name  danceability  energy  \
# 6rdmyLJtIibFRaCU7XRg3x                       Love Like         0.651   0.646
# 2WN7xpcY4zmcqF57HFEGZY  Better Believe (ft The Weeknd)         0.799   0.569
# 0jTTjg6q4jsd2RhuHwTvLj                He Said She Said         0.694   0.709
#
#                         key  loudness  mode  speechiness  acousticness  \
# 6rdmyLJtIibFRaCU7XRg3x    1    -5.305     1       0.0264        0.0243
# 2WN7xpcY4zmcqF57HFEGZY    0    -7.821     1       0.3180        0.1540
# 0jTTjg6q4jsd2RhuHwTvLj    7    -6.205     0       0.1030        0.0966
#
#                         instrumentalness  ...  time_signature  classical  \
# 6rdmyLJtIibFRaCU7XRg3x               0.0  ...               4          0
# 2WN7xpcY4zmcqF57HFEGZY               0.0  ...               4          0
# 0jTTjg6q4jsd2RhuHwTvLj               0.0  ...               4          0
#
#                         country  edm  hip-hop  jazz  pop  rap  rnb  rock
# 6rdmyLJtIibFRaCU7XRg3x        1    0        0     0    0    0    0     0
# 2WN7xpcY4zmcqF57HFEGZY        0    0        0     0    0    1    0     0
# 0jTTjg6q4jsd2RhuHwTvLj        0    0        0     0    1    0    0     0
#
# [3 rows x 24 columns]

# %%
# Inspect two previously duplicated tracks and check if more than one genre is listed
all_tracks_cleaned.loc[['1rIKgCH4H52lrvDcz50hS8', '2wxO3ZydJTZRi4Bbc02q7i']]
# Out:
#                                            artists       name  danceability  \
# 1rIKgCH4H52lrvDcz50hS8              [Zara Larsson]  Lush Life         0.694
# 2wxO3ZydJTZRi4Bbc02q7i  [Scarface, Johnny P, 2Pac]      Smile         0.700
#
#                         energy  key  loudness  mode  speechiness  \
# 1rIKgCH4H52lrvDcz50hS8   0.712    7    -3.923     0        0.046
# 2wxO3ZydJTZRi4Bbc02q7i   0.402    5    -9.930     0        0.278
#
#                         acousticness  instrumentalness  ...  time_signature  \
# 1rIKgCH4H52lrvDcz50hS8        0.1320          0.000000  ...               4
# 2wxO3ZydJTZRi4Bbc02q7i        0.0498          0.000001  ...               4
#
#                         classical  country  edm  hip-hop  jazz  pop  rap  rnb  \
# 1rIKgCH4H52lrvDcz50hS8          0        0    1        0     0    1    0    0
# 2wxO3ZydJTZRi4Bbc02q7i          0        0    0        1     0    0    1    0
#
#                         rock
# 1rIKgCH4H52lrvDcz50hS8     0
# 2wxO3ZydJTZRi4Bbc02q7i     0
#
# [2 rows x 24 columns]

# %%
all_tracks_cleaned.to_pickle("../data/spotify_dataset_all.pkl")
