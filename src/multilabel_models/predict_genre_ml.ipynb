# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
sns.set()

# %% [markdown]
# Read data

# %%
tracks = pd.read_pickle("../../data/spotify_dataset_all.pkl")

# %% [markdown]
# Remove unnecessary variables

# %%
cleaned_tracks = tracks.drop(['artists', 'name'], axis=1)
cleaned_tracks.head(n=1)
# Out:
#                         danceability  energy  key  loudness  mode  \
# 5bu9A6uphPWg39RC3ZKeku         0.454  0.0139    4   -29.966     0
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# 5bu9A6uphPWg39RC3ZKeku       0.0514         0.995             0.943    0.0736
#
#                         valence  ...  time_signature  classical  country  edm  \
# 5bu9A6uphPWg39RC3ZKeku    0.244  ...               4          1        0    0
#
#                         hip-hop  jazz  pop  rap  rnb  rock
# 5bu9A6uphPWg39RC3ZKeku        0     0    0    0    0     0
#
# [1 rows x 22 columns]

# %% [markdown]
# Normalise

# %%
GENRES = ['classical', 'country', 'edm', 'hip-hop', 'jazz', 'pop', 'rap', 'rnb', 'rock']

# %%
normaliser = MinMaxScaler()

# %%
cleaned_tracks_no_genres = cleaned_tracks.drop(GENRES, axis=1)
normalised_tracks = normaliser.fit_transform(cleaned_tracks_no_genres)
cleaned_tracks_no_genres = pd.DataFrame(normalised_tracks, columns=cleaned_tracks_no_genres.columns).set_index(cleaned_tracks_no_genres.index)
cleaned_tracks = pd.merge(cleaned_tracks_no_genres, cleaned_tracks[GENRES], left_index=True, right_index=True)

cleaned_tracks.sample(n=3)
# Out:
#                         danceability    energy       key  loudness  mode  \
# 3xKsGYkJKy0bbQuUHRYrei      0.388286  0.970916  0.454545  0.886077   1.0
# 3yXzqYnNtLHXDOuTjZonXL      0.645336  0.562739  0.909091  0.831030   0.0
# 53QF56cjZA9RTuuMZDrSA6      0.457701  0.302989  0.363636  0.754261   1.0
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# 3xKsGYkJKy0bbQuUHRYrei     0.199947      0.000324          0.000686  0.081935
# 3yXzqYnNtLHXDOuTjZonXL     0.647775      0.702810          0.000000  0.154755
# 53QF56cjZA9RTuuMZDrSA6     0.054290      0.696786          0.000000  0.105034
#
#                          valence  ...  time_signature  classical  country  \
# 3xKsGYkJKy0bbQuUHRYrei  0.505877  ...            0.75          0        0
# 3yXzqYnNtLHXDOuTjZonXL  0.367523  ...            0.75          0        0
# 53QF56cjZA9RTuuMZDrSA6  0.119942  ...            0.50          0        0
#
#                         edm  hip-hop  jazz  pop  rap  rnb  rock
# 3xKsGYkJKy0bbQuUHRYrei    0        0     0    0    0    0     1
# 3yXzqYnNtLHXDOuTjZonXL    0        0     0    0    0    1     0
# 53QF56cjZA9RTuuMZDrSA6    0        0     0    1    0    0     0
#
# [3 rows x 22 columns]

# %% [markdown]
# Lookup proportions

# %%
counts = {}

for genre in GENRES:
    count = cleaned_tracks.loc[cleaned_tracks[genre] == 1].shape[0]
    counts[genre] = count

counts
# Out:
# {'classical': 432,
#  'country': 608,
#  'edm': 980,
#  'hip-hop': 969,
#  'jazz': 499,
#  'pop': 1220,
#  'rap': 885,
#  'rnb': 735,
#  'rock': 1136}

# %% [markdown]
# Resample to get equal counts of all genres

# %%
resampled_df = pd.DataFrame()

for genre in GENRES:
    genre_df = cleaned_tracks.loc[cleaned_tracks[genre] == 1].sample(n=420)
    resampled_df = pd.concat([resampled_df, genre_df])

resampled_df.sample(n=9)
# Out:
#                         danceability    energy       key  loudness  mode  \
# 1SHixA41Vy0TTlJJSX9Gbo      0.317787  0.207714  0.909091  0.581753   1.0
# 5KBUiiDRPsocZlY2v3EtRk      0.872017  0.641967  0.909091  0.830538   0.0
# 5IUtvfNvOyVYZUa6AJFrnP      0.781996  0.510588  0.363636  0.851320   0.0
# 3gEm37rTZf4mf3xmr3aTZp      0.073753  0.003786  0.363636  0.281034   1.0
# 4pDU8T52yTGZutyDQd8qSF      0.404555  0.482507  0.454545  0.830336   1.0
# 51rXHuKN8Loc4sUlKPODgH      0.633406  0.706152  0.090909  0.867355   1.0
# 2TScNFVGQ6PQS9cGLMyULI      0.364425  0.419325  0.181818  0.765100   1.0
# 0BKNINLyNmQUvs9biD0ynB      0.366594  0.335082  0.909091  0.728506   0.0
# 7C5egNfLY7qELLhPnQIFtP      0.112798  0.168601  0.818182  0.410028   1.0
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# 1SHixA41Vy0TTlJJSX9Gbo     0.043432      0.951807          0.934827  0.068987
# 5KBUiiDRPsocZlY2v3EtRk     0.369703      0.061543          0.000108  0.211726
# 5IUtvfNvOyVYZUa6AJFrnP     0.051642      0.143571          0.000000  0.105034
# 3gEm37rTZf4mf3xmr3aTZp     0.050847      0.963855          0.634420  0.061115
# 4pDU8T52yTGZutyDQd8qSF     0.028072      0.639557          0.000000  0.178579
# 51rXHuKN8Loc4sUlKPODgH     0.732521      0.000813          0.000000  0.118500
# 2TScNFVGQ6PQS9cGLMyULI     0.025159      0.374496          0.000000  0.284235
# 0BKNINLyNmQUvs9biD0ynB     0.088718      0.830321          0.763747  0.110213
# 7C5egNfLY7qELLhPnQIFtP     0.046081      0.995984          0.954175  0.079967
#
#                          valence  ...  time_signature  classical  country  \
# 1SHixA41Vy0TTlJJSX9Gbo  0.315510  ...            0.75          1        0
# 5KBUiiDRPsocZlY2v3EtRk  0.766982  ...            0.75          0        0
# 5IUtvfNvOyVYZUa6AJFrnP  0.098096  ...            0.75          0        0
# 3gEm37rTZf4mf3xmr3aTZp  0.000000  ...            0.75          1        0
# 4pDU8T52yTGZutyDQd8qSF  0.182357  ...            0.75          0        1
# 51rXHuKN8Loc4sUlKPODgH  0.366483  ...            0.75          0        0
# 2TScNFVGQ6PQS9cGLMyULI  0.708728  ...            0.75          0        1
# 0BKNINLyNmQUvs9biD0ynB  0.301987  ...            0.75          0        0
# 7C5egNfLY7qELLhPnQIFtP  0.087694  ...            1.00          1        0
#
#                         edm  hip-hop  jazz  pop  rap  rnb  rock
# 1SHixA41Vy0TTlJJSX9Gbo    0        0     0    0    0    0     0
# 5KBUiiDRPsocZlY2v3EtRk    0        1     0    0    0    0     0
# 5IUtvfNvOyVYZUa6AJFrnP    0        0     0    1    0    0     0
# 3gEm37rTZf4mf3xmr3aTZp    0        0     0    0    0    0     0
# 4pDU8T52yTGZutyDQd8qSF    0        0     0    0    0    0     0
# 51rXHuKN8Loc4sUlKPODgH    0        1     0    0    1    0     0
# 2TScNFVGQ6PQS9cGLMyULI    0        0     0    0    0    0     0
# 0BKNINLyNmQUvs9biD0ynB    0        0     1    0    0    0     0
# 7C5egNfLY7qELLhPnQIFtP    0        0     0    0    0    0     0
#
# [9 rows x 22 columns]

# %% [markdown]
# Prepare data for models

# %%
X = resampled_df.drop(GENRES, axis=1).to_numpy()
y = resampled_df.loc[:, GENRES].to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# Models

# %%
from skmultilearn.problem_transform import LabelPowerset
from sklearn.linear_model import LogisticRegression

cls = LabelPowerset(LogisticRegression(max_iter=400))

cls.fit(X_train, y_train)

pred = cls.predict(X_test)

accuracy_score(y_test, pred)
# Out:
# 0.49603174603174605
