# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
GENRES = ["classical", "country", "edm", "hip-hop", "jazz", "pop", "rap", "rnb", "rock"]

# %%
all_tracks_df = pd.DataFrame()
for genre in GENRES:
    genre_df = pd.read_pickle(f"../../data/spotify_dataset_{genre}.pkl")
    all_tracks_df = pd.concat([all_tracks_df, genre_df])

# Dropping duplicates
all_tracks_df = all_tracks_df[~all_tracks_df.index.duplicated(keep="first")]
cleaned_tracks_df = all_tracks_df.drop(["artists", "name"], axis=1)

cleaned_tracks_df
# Out:
#                             genre  danceability   energy  key  loudness  mode  \
# 5bu9A6uphPWg39RC3ZKeku  classical        0.4540  0.01390    4   -29.966     0
# 1Oo7XEqkrwifJn17aA0ocF  classical        0.2990  0.00626    9   -30.923     1
# 1upQiytDIEZfl9ItruoXuC  classical        0.0939  0.03360    2   -24.041     0
# 47DAIw0cnLLHEXcuUHHC6a  classical        0.5000  0.12800    7   -18.042     1
# 3DNRdudZ2SstnDCVKFdXxG  classical        0.1840  0.00527    1   -37.264     0
# ...                           ...           ...      ...  ...       ...   ...
# 6vUssnJuFxgw1EFG717Kd5       rock        0.4000  0.51600    9    -9.317     1
# 1p50Ir1Hm6Sa1urjaLGi7L       rock        0.6010  0.83100    2    -8.582     1
# 7LbfuQVct78YoghmoPtsQ8       rock        0.6710  0.40500    0   -10.052     1
# 3T76zPJz3tWL27FrjJe2ot       rock        0.3810  0.83800    6    -6.562     0
# 2VnkxWob7ooT5NrN9WtctI       rock        0.3480  0.63300    2    -7.025     1
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# 5bu9A6uphPWg39RC3ZKeku       0.0514      0.995000          0.943000    0.0736
# 1Oo7XEqkrwifJn17aA0ocF       0.0478      0.994000          0.901000    0.0823
# 1upQiytDIEZfl9ItruoXuC       0.0606      0.927000          0.830000    0.0954
# 47DAIw0cnLLHEXcuUHHC6a       0.0489      0.953000          0.618000    0.0924
# 3DNRdudZ2SstnDCVKFdXxG       0.0432      0.995000          0.887000    0.1730
# ...                             ...           ...               ...       ...
# 6vUssnJuFxgw1EFG717Kd5       0.0316      0.779000          0.000024    0.2040
# 1p50Ir1Hm6Sa1urjaLGi7L       0.1700      0.000860          0.000000    0.1020
# 7LbfuQVct78YoghmoPtsQ8       0.0392      0.385000          0.000000    0.1320
# 3T76zPJz3tWL27FrjJe2ot       0.0709      0.004600          0.000038    0.1010
# 2VnkxWob7ooT5NrN9WtctI       0.0317      0.000285          0.011500    0.1220
#
#                         valence    tempo  duration_ms  time_signature
# 5bu9A6uphPWg39RC3ZKeku   0.2440  130.253       184853               4
# 1Oo7XEqkrwifJn17aA0ocF   0.0634   69.043       378733               4
# 1upQiytDIEZfl9ItruoXuC   0.0516   67.359       207267               3
# 47DAIw0cnLLHEXcuUHHC6a   0.2580  101.849       409227               4
# 3DNRdudZ2SstnDCVKFdXxG   0.1510  170.612       315427               3
# ...                         ...      ...          ...             ...
# 6vUssnJuFxgw1EFG717Kd5   0.5220  145.544       129160               3
# 1p50Ir1Hm6Sa1urjaLGi7L   0.2960  120.962       211787               4
# 7LbfuQVct78YoghmoPtsQ8   0.8280   99.678       265067               4
# 3T76zPJz3tWL27FrjJe2ot   0.5810  118.214       219400               4
# 2VnkxWob7ooT5NrN9WtctI   0.7140  146.356       246101               4
#
# [6631 rows x 14 columns]

# %%
cleaned_tracks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6631 entries, 5bu9A6uphPWg39RC3ZKeku to 2VnkxWob7ooT5NrN9WtctI
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   genre             6631 non-null   object
#  1   danceability      6631 non-null   float64
#  2   energy            6631 non-null   float64
#  3   key               6631 non-null   int64
#  4   loudness          6631 non-null   float64
#  5   mode              6631 non-null   int64
#  6   speechiness       6631 non-null   float64
#  7   acousticness      6631 non-null   float64
#  8   instrumentalness  6631 non-null   float64
#  9   liveness          6631 non-null   float64
#  10  valence           6631 non-null   float64
#  11  tempo             6631 non-null   float64
#  12  duration_ms       6631 non-null   int64
#  13  time_signature    6631 non-null   int64
# dtypes: float64(9), int64(4), object(1)
# memory usage: 777.1+ KB

# %%
all_tracks_df['genre'].value_counts().plot.pie(autopct='%1.1f%%', figsize=(10,10));

# %%
plt.figure(figsize=(15,8))
mask = np.triu(np.ones_like(cleaned_tracks_df.corr(), dtype=bool))
sns.heatmap(cleaned_tracks_df.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap="PiYG");

# %% [markdown]
# Loudness and Energy seem to have a strong positive correlation. Acousticness and Energy have a strong negative correlation. There are some other weaker relationships too, such as Acousticness/Loudness, Instrumentalness/Loudness, Instrumentalness/Acousticness and Valence/Danceability.

# %%
cleaned_tracks_df.hist(figsize=(20,15));

# %% [markdown]
# Danceability and Tempo are the most normally distributed (with slight negative and positive skew respectively).

# %%
cleaned_tracks_df.describe()
# Out:
#        danceability       energy          key     loudness         mode  \
# count   6631.000000  6631.000000  6631.000000  6631.000000  6631.000000
# mean       0.602172     0.607077     5.255919    -8.637084     0.618006
# std        0.177102     0.245664     3.551065     5.643976     0.485912
# min        0.061000     0.000885     0.000000   -43.738000     0.000000
# 25%        0.494500     0.465000     2.000000   -10.084000     0.000000
# 50%        0.620000     0.652000     5.000000    -6.893000     1.000000
# 75%        0.729000     0.798000     8.000000    -5.110500     1.000000
# max        0.983000     0.998000    11.000000     0.915000     1.000000
#
#        speechiness  acousticness  instrumentalness     liveness      valence  \
# count  6631.000000   6631.000000       6631.000000  6631.000000  6631.000000
# mean      0.093227      0.273074          0.113291     0.178383     0.481571
# std       0.089200      0.320202          0.265305     0.141731     0.244862
# min       0.022400      0.000003          0.000000     0.013600     0.023700
# 25%       0.036800      0.023300          0.000000     0.092750     0.287000
# 50%       0.050300      0.122000          0.000013     0.121000     0.485000
# 75%       0.108500      0.433500          0.008215     0.222000     0.675500
# max       0.400000      0.996000          0.982000     0.979000     0.985000
#
#              tempo   duration_ms  time_signature
# count  6631.000000  6.631000e+03     6631.000000
# mean    118.737153  2.396629e+05        3.929724
# std      28.661549  7.933806e+04        0.350662
# min      42.313000  1.201330e+05        1.000000
# 25%      95.833000  1.918175e+05        4.000000
# 50%     119.930000  2.232630e+05        4.000000
# 75%     135.068000  2.655875e+05        4.000000
# max     210.857000  1.148947e+06        5.000000
